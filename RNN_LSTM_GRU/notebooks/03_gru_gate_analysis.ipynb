# %% [markdown]
# # 03 · GRU 门控分析
#
# 前置条件：读完 07_gru_core，或完成 exercises 中 CORE-G01 至 G07。检查 reset/update gate 在不同 delay 下的行为。

# %%
import matplotlib.pyplot as plt
import torch
from gru.torch_impl import ManualRecurrentLayer

torch.manual_seed(42)
# TODO: 暴露或通过 hook 记录 r/z；不要改变正式 forward 的返回契约。

# %% [markdown]
# ## 必做分析
#
# - 绘制 update gate 随时间的位置统计。
# - 比较 query 位置前后 reset gate 的变化。
# - 用一个小样例验证 reset-after 与教材常见公式确实可能输出不同结果。

# %% [markdown]
# ## 结论
#
# - update gate 对长期保持的作用：
# - reset gate 在本任务中的作用：
# - 与 LSTM 相比的主要取舍：
