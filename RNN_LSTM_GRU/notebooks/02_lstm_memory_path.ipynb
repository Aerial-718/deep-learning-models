# %% [markdown]
# # 02 · LSTM 记忆通道
#
# 前置条件：读完 06_lstm_core，或完成 exercises 中 CORE-L01 至 L07。重点区分 hidden-state 与 cell-state 梯度。

# %%
import matplotlib.pyplot as plt
import torch
from lstm.torch_impl import ManualRecurrentLayer
from lstm.experiments import set_forget_bias

torch.manual_seed(42)
# TODO: forget bias 分别设为 0、1、2，记录 delayed-recall 指标和 dh/dc 曲线。

# %% [markdown]
# ## 必做分析
#
# 1. 同图比较 `||dL/dh_t||` 与 `||dL/dc_t||`。
# 2. 记录 forget gate 的均值与饱和比例。
# 3. 解释较大 forget bias 对训练早期的影响，而不是只报告最终准确率。

# %% [markdown]
# ## 结论
#
# - 最稳定的 forget bias：
# - cell path 相比 hidden path 的观察：
# - 仍然失败的 delay 与可能原因：
