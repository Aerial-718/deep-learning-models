# %% [markdown]
# # 01 · Vanilla RNN 梯度流
#
# 前置条件：读完 05_vanilla_rnn_core，或完成 exercises 中 CORE-V01 至 V08。研究序列长度、循环权重谱半径与梯度范数的关系。

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from vanilla_rnn.torch_impl import ManualRecurrentLayer

torch.manual_seed(42)
# TODO: 对长度 5、20、50、100 的序列记录每个时间位置的隐藏梯度范数。

# %% [markdown]
# ## 必做图表
#
# - x 轴为距 loss 的时间距离，y 轴为 log gradient norm。
# - 比较三个循环权重缩放系数。
# - 标出梯度裁剪发生的位置，但同时保留裁剪前 norm。

# %% [markdown]
# ## 结论
#
# - 梯度消失最明显的配置：
# - 梯度爆炸最明显的配置：
# - 裁剪能解决与不能解决的问题：
