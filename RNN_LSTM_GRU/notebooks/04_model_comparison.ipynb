# %% [markdown]
# # 04 · RNN / LSTM / GRU 统一比较
#
# 只使用相同数据切分、hidden size、优化器、训练步数和三个固定种子的正式 run。

# %%
from pathlib import Path
import json
import matplotlib.pyplot as plt
import numpy as np

artifact_root = Path('../artifacts')
# TODO: 读取 compare_models.py 产生的 CSV/JSON，不要手工复制数字。

# %% [markdown]
# ## 必做结果
#
# 1. delay 5/20/50 的准确率均值与标准差。
# 2. 字符模型 validation/test BPC。
# 3. 参数量、训练吞吐量与峰值内存。
# 4. 梯度范数随时间距离的曲线。
# 5. 相同 prompt、temperature、top-k 和 seed 的生成样例。

# %% [markdown]
# ## 最终结论
#
# - Vanilla RNN 的适用边界：
# - LSTM 的优势与额外成本：
# - GRU 的优势与额外成本：
# - 如果重新选择模型，你会根据哪些证据决策：
# - 本实验不能支持的结论：
